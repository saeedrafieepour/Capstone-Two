# %%
import requests
import numpy as np
import pandas as pd

import ydata_profiling
from ydata_profiling.utils.cache import cache_file

# %%
loan_data = pd.read_csv("C:\\Users\\saeed.rafieepour\\Desktop\\Training\\Springboard DS Course\\7. Data Wrangling-Capstone 2 Project\\7.6 Data Wrangling capstone project two\\raw data\\archive\\loan.csv")
# Out:
# C:\Users\saeed.rafieepour\AppData\Local\Temp\ipykernel_24620\1586605488.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data = pd.read_csv("C:\\Users\\saeed.rafieepour\\Desktop\\Training\\Springboard DS Course\\7. Data Wrangling-Capstone 2 Project\\7.6 Data Wrangling capstone project two\\raw data\\archive\\loan.csv")

# %% [markdown]
# ### Inline report without saving object

# %%
profile_report = loan_data.profile_report(sort=None, html={'style':{'full_width': True}}, progress_bar=False)

# %%
#profile_report.to_widgets()

# %%
profile_report.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24620\3171028288.py in <module>
# ----> 1 profile_report.to_notebook_iframe()
#
# ~\Anaconda3\lib\site-packages\typeguard\__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# ~\Anaconda3\lib\site-packages\ydata_profiling\profile_report.py in to_notebook_iframe(self)
#     496         with warnings.catch_warnings():
#     497             warnings.simplefilter("ignore")
# --> 498             display(get_notebook_iframe(self.config, self))
#     499
#     500     def to_widgets(self) -> None:
#
# ...
